# %% [markdown]
# # This notebook is to create pseudobulk cells for each of the 3 cell atlases

# %% [markdown]
# ## Imports

# %%
import scanpy.api as sc
import numpy as np
import pandas as pd
import scanpy
import scipy
import pandas as pd
# Out:
# /work/sduknn/Andreas/bin/python_deps/lib/python3.6/site-packages/numba/errors.py:105: UserWarning: Insufficiently recent colorama version found. Numba requires colorama >= 0.3.9
#   warnings.warn(msg)

# %%
#Loading datasets
mca = scanpy.read_h5ad('/work/sduknn/Andreas/TM_MCA/MCA/mca_scanpy_no_processing.h5ad')
facs = scanpy.read_h5ad('/work/sduknn/Andreas/TM_MCA/TM/tm_facs_scanpy_no_processing.h5ad')
droplet = scanpy.read_h5ad('/work/sduknn/Andreas/TM_MCA/TM/tm_droplet_scanpy_no_processing.h5ad')

# %%
#getting annotation from scmap projection of TM - 10x
mca_ann = pd.read_csv('/work/sduknn/Andreas/TM_MCA/MCA/mca_annotation_projected_from_drop.tsv', sep= '\t')

facs_ann = pd.read_csv('/work/sduknn/Andreas/TM_MCA/TM/facs_annotation_projected_from_drop.tsv', sep= '\t')

# %%
mca.obs['original_annotation'] =  mca_ann['original'].values
mca.obs['from_droplet'] =  mca_ann['projected_drom_droplet'].values

facs.obs['original_annotation'] =  facs_ann['original'].values
facs.obs['from_droplet'] =  facs_ann['projected_drom_droplet'].values

# %% [markdown]
# ## Computing pseudobulk cells

# %% [markdown]
# #### Here example with 20 cell pseudobulk cells. (though we used 50 cell pseudobulk)

# %%
n_cells = 20

def pseudobulk(anndata = object, tissue = str, celltype = str, n_cells = int):
    """Averages cell expressions of a Scanpy object. Average of n cells from each celltype in each tissue.
    
    anndata : An anndata object
    tissue : A string representing the column name of the tissue attribute within the anndata.obs pandas dataframe
    celltype : Like tissue, but column name of the celltype column
    n-cells : Integer representing the ammount of cells to average over
    
    Returns : An anndata object with the averaged expression profiles
    """
    avg_mat = pd.DataFrame()
    ann_mat = pd.DataFrame()
    meta_mat = pd.DataFrame()
    for tiss in set(anndata.obs[tissue]):
        a = anndata[anndata.obs[tissue] == tiss]
        print('Subsetting tissue: '+ str(tiss))
        
        for clust in set(a.obs[celltype]):
            b = a[a.obs[celltype] == clust]
            print('Subsetting celltype: '+str(clust)+' in '+ str(tiss))
            
            n = b.n_obs // n_cells
            if n != 0:
                x = 1
                for i in range(0, n*n_cells, n_cells):
                    x = x + 1
                    cell_numbers = [*range(i,i+n_cells)]

                    avg = pd.DataFrame(data = b.X[cell_numbers].sum( axis = 0).T, index = b.var_names, columns = [str(tiss)+'_' + str(clust) + '_' +str(x)])
                    avg_mat = avg_mat.append(avg.T)
                    ann_mat = ann_mat.append(pd.DataFrame(data=clust, index = [str(tiss)+'_'+str(clust) + '_' +str(x)], columns = ['celltype']))
                    meta_mat = meta_mat.append(pd.DataFrame(data=tiss, index = [str(tiss)+'_'+str(clust) + '_' +str(x)], columns = ['tissue']))
    scanpy_object = sc.AnnData(X=(scipy.sparse.csr_matrix(avg_mat)), obs=ann_mat, var= pd.DataFrame(data = None, index = avg_mat.columns))
    return(scanpy_object)

# %%
## 20 cell pseudobulk from TM - 10X
droplet = pseudobulk(droplet, 'tissue', 'cell_ontology_class', n_cells)
# Out:
# Subsetting tissue: Tongue
# Subsetting celltype: basal cell of epidermis in Tongue
# Subsetting celltype: keratinocyte in Tongue
# Subsetting celltype: Langerhans cell in Tongue
# Subsetting tissue: Lung
# Subsetting celltype: nan in Lung
# Subsetting celltype: classical monocyte in Lung
# Subsetting celltype: leukocyte in Lung
# Subsetting celltype: alveolar macrophage in Lung
# Subsetting celltype: myeloid cell in Lung
# Subsetting celltype: T cell in Lung
# Subsetting celltype: natural killer cell in Lung
# Subsetting celltype: lung endothelial cell in Lung
# Subsetting celltype: ciliated columnar cell of tracheobronchial tree in Lung
# Subsetting celltype: non-classical monocyte in Lung
# Subsetting celltype: type II pneumocyte in Lung
# Subsetting celltype: mast cell in Lung
# Subsetting celltype: B cell in Lung
# Subsetting celltype: stromal cell in Lung
# Subsetting tissue: Mammary_Gland
# Subsetting celltype: basal cell in Mammary_Gland
# Subsetting celltype: T cell in Mammary_Gland
# Subsetting celltype: luminal epithelial cell of mammary gland in Mammary_Gland
# Subsetting celltype: endothelial cell in Mammary_Gland
# Subsetting celltype: macrophage in Mammary_Gland
# Subsetting celltype: B cell in Mammary_Gland
# Subsetting celltype: stromal cell in Mammary_Gland
# Subsetting tissue: Bladder
# Subsetting celltype: endothelial cell in Bladder
# Subsetting celltype: bladder urothelial cell in Bladder
# Subsetting celltype: leukocyte in Bladder
# Subsetting celltype: bladder cell in Bladder
# Subsetting tissue: Limb_Muscle
# Subsetting celltype: nan in Limb_Muscle
# Subsetting celltype: skeletal muscle satellite cell in Limb_Muscle
# Subsetting celltype: T cell in Limb_Muscle
# Subsetting celltype: mesenchymal stem cell in Limb_Muscle
# Subsetting celltype: endothelial cell in Limb_Muscle
# Subsetting celltype: macrophage in Limb_Muscle
# Subsetting celltype: B cell in Limb_Muscle
# Subsetting tissue: Heart_and_Aorta
# Subsetting celltype: nan in Heart_and_Aorta
# Subsetting celltype: endocardial cell in Heart_and_Aorta
# Subsetting celltype: cardiac muscle cell in Heart_and_Aorta
# Subsetting celltype: endothelial cell in Heart_and_Aorta
# Subsetting celltype: fibroblast in Heart_and_Aorta
# Subsetting tissue: Trachea
# Subsetting celltype: nan in Trachea
# Subsetting celltype: mesenchymal cell in Trachea
# Subsetting celltype: neuroendocrine cell in Trachea
# Subsetting celltype: endothelial cell in Trachea
# Subsetting celltype: blood cell in Trachea
# Subsetting celltype: epithelial cell in Trachea
# Subsetting tissue: Spleen
# Subsetting celltype: nan in Spleen
# Subsetting celltype: T cell in Spleen
# Subsetting celltype: natural killer cell in Spleen
# Subsetting celltype: macrophage in Spleen
# Subsetting celltype: dendritic cell in Spleen
# Subsetting celltype: B cell in Spleen
# Subsetting tissue: Thymus
# Subsetting celltype: immature T cell in Thymus
# Subsetting celltype: nan in Thymus
# Subsetting celltype: DN1 thymic pro-T cell in Thymus
# Subsetting celltype: leukocyte in Thymus
# Subsetting tissue: Liver
# Subsetting celltype: nan in Liver
# Subsetting celltype: endothelial cell of hepatic sinusoid in Liver
# Subsetting celltype: duct epithelial cell in Liver
# Subsetting celltype: leukocyte in Liver
# Subsetting celltype: hepatocyte in Liver
# Subsetting tissue: Marrow
# Subsetting celltype: nan in Marrow
# Subsetting celltype: basophil in Marrow
# Subsetting celltype: immature B cell in Marrow
# Subsetting celltype: granulocytopoietic cell in Marrow
# Subsetting celltype: late pro-B cell in Marrow
# Subsetting celltype: Fraction A pre-pro B cell in Marrow
# Subsetting celltype: hematopoietic precursor cell in Marrow
# Subsetting celltype: proerythroblast in Marrow
# Subsetting celltype: promonocyte in Marrow
# Subsetting celltype: T cell in Marrow
# Subsetting celltype: granulocyte in Marrow
# Subsetting celltype: monocyte in Marrow
# Subsetting celltype: macrophage in Marrow
# Subsetting celltype: erythroblast in Marrow
# Subsetting celltype: early pro-B cell in Marrow
# Subsetting tissue: Kidney
# Subsetting celltype: nan in Kidney
# Subsetting celltype: mesangial cell in Kidney
# Subsetting celltype: leukocyte in Kidney
# Subsetting celltype: kidney capillary endothelial cell in Kidney
# Subsetting celltype: kidney proximal straight tubule epithelial cell in Kidney
# Subsetting celltype: kidney loop of Henle ascending limb epithelial cell in Kidney
# Subsetting celltype: macrophage in Kidney
# Subsetting celltype: kidney collecting duct epithelial cell in Kidney
# Subsetting celltype: kidney cell in Kidney

# %%
droplet
# Out:
# AnnData object with n_obs × n_vars = 2713 × 23433
#     obs: 'celltype'

# %%
## 20 cell pseudobulk from TM - SS2
facs = pseudobulk(facs, 'tissue', 'from_droplet', n_cells)
# Out:
# Subsetting tissue: Pancreas
# Subsetting celltype: classical monocyte in Pancreas
# Subsetting celltype: skeletal muscle satellite cell in Pancreas
# Subsetting celltype: endocardial cell in Pancreas
# Subsetting celltype: myeloid cell in Pancreas
# Subsetting celltype: ciliated columnar cell of tracheobronchial tree in Pancreas
# Subsetting celltype: epithelial cell in Pancreas
# Subsetting celltype: basal cell of epidermis in Pancreas
# Subsetting celltype: mesenchymal cell in Pancreas
# Subsetting celltype: immature B cell in Pancreas
# Subsetting celltype: mesangial cell in Pancreas
# Subsetting celltype: kidney capillary endothelial cell in Pancreas
# Subsetting celltype: type II pneumocyte in Pancreas
# Subsetting celltype: fibroblast in Pancreas
# Subsetting celltype: DN1 thymic pro-T cell in Pancreas
# Subsetting celltype: endothelial cell of hepatic sinusoid in Pancreas
# Subsetting celltype: mesenchymal stem cell in Pancreas
# Subsetting celltype: natural killer cell in Pancreas
# Subsetting celltype: endothelial cell in Pancreas
# Subsetting celltype: macrophage in Pancreas
# Subsetting celltype: stromal cell in Pancreas
# Subsetting celltype: neuroendocrine cell in Pancreas
# Subsetting celltype: luminal epithelial cell of mammary gland in Pancreas
# Subsetting celltype: lung endothelial cell in Pancreas
# Subsetting celltype: unassigned in Pancreas
# Subsetting celltype: B cell in Pancreas
# Subsetting celltype: kidney collecting duct epithelial cell in Pancreas
# Subsetting celltype: blood cell in Pancreas
# Subsetting celltype: kidney cell in Pancreas
# Subsetting tissue: Large_Intestine
# Subsetting celltype: mesangial cell in Large_Intestine
# Subsetting celltype: skeletal muscle satellite cell in Large_Intestine
# Subsetting celltype: bladder cell in Large_Intestine
# Subsetting celltype: hematopoietic precursor cell in Large_Intestine
# Subsetting celltype: bladder urothelial cell in Large_Intestine
# Subsetting celltype: luminal epithelial cell of mammary gland in Large_Intestine
# Subsetting celltype: mesenchymal stem cell in Large_Intestine
# Subsetting celltype: unassigned in Large_Intestine
# Subsetting celltype: B cell in Large_Intestine
# Subsetting celltype: kidney cell in Large_Intestine
# Subsetting celltype: epithelial cell in Large_Intestine
# Subsetting tissue: Brain_Myeloid
# Subsetting celltype: basophil in Brain_Myeloid
# Subsetting celltype: classical monocyte in Brain_Myeloid
# Subsetting celltype: endocardial cell in Brain_Myeloid
# Subsetting celltype: bladder cell in Brain_Myeloid
# Subsetting celltype: myeloid cell in Brain_Myeloid
# Subsetting celltype: granulocyte in Brain_Myeloid
# Subsetting celltype: Langerhans cell in Brain_Myeloid
# Subsetting celltype: granulocytopoietic cell in Brain_Myeloid
# Subsetting celltype: non-classical monocyte in Brain_Myeloid
# Subsetting celltype: fibroblast in Brain_Myeloid
# Subsetting celltype: natural killer cell in Brain_Myeloid
# Subsetting celltype: mast cell in Brain_Myeloid
# Subsetting celltype: endothelial cell in Brain_Myeloid
# Subsetting celltype: macrophage in Brain_Myeloid
# Subsetting celltype: hepatocyte in Brain_Myeloid
# Subsetting celltype: leukocyte in Brain_Myeloid
# Subsetting celltype: Fraction A pre-pro B cell in Brain_Myeloid
# Subsetting celltype: alveolar macrophage in Brain_Myeloid
# Subsetting celltype: bladder urothelial cell in Brain_Myeloid
# Subsetting celltype: unassigned in Brain_Myeloid
# Subsetting celltype: dendritic cell in Brain_Myeloid
# Subsetting celltype: blood cell in Brain_Myeloid
# Subsetting celltype: kidney cell in Brain_Myeloid
# Subsetting tissue: Brain_Non-Myeloid
# Subsetting celltype: basophil in Brain_Non-Myeloid
# Subsetting celltype: keratinocyte in Brain_Non-Myeloid
# Subsetting celltype: classical monocyte in Brain_Non-Myeloid
# Subsetting celltype: skeletal muscle satellite cell in Brain_Non-Myeloid
# Subsetting celltype: endocardial cell in Brain_Non-Myeloid
# Subsetting celltype: granulocyte in Brain_Non-Myeloid
# Subsetting celltype: epithelial cell in Brain_Non-Myeloid
# Subsetting celltype: basal cell of epidermis in Brain_Non-Myeloid
# Subsetting celltype: Langerhans cell in Brain_Non-Myeloid
# Subsetting celltype: mesangial cell in Brain_Non-Myeloid
# Subsetting celltype: kidney capillary endothelial cell in Brain_Non-Myeloid
# Subsetting celltype: hematopoietic precursor cell in Brain_Non-Myeloid
# Subsetting celltype: immature T cell in Brain_Non-Myeloid
# Subsetting celltype: fibroblast in Brain_Non-Myeloid
# Subsetting celltype: DN1 thymic pro-T cell in Brain_Non-Myeloid
# Subsetting celltype: late pro-B cell in Brain_Non-Myeloid
# Subsetting celltype: T cell in Brain_Non-Myeloid
# Subsetting celltype: natural killer cell in Brain_Non-Myeloid
# Subsetting celltype: mesenchymal stem cell in Brain_Non-Myeloid
# Subsetting celltype: mast cell in Brain_Non-Myeloid
# Subsetting celltype: endothelial cell in Brain_Non-Myeloid
# Subsetting celltype: macrophage in Brain_Non-Myeloid
# Subsetting celltype: hepatocyte in Brain_Non-Myeloid
# Subsetting celltype: early pro-B cell in Brain_Non-Myeloid
# Subsetting celltype: basal cell in Brain_Non-Myeloid
# Subsetting celltype: stromal cell in Brain_Non-Myeloid
# Subsetting celltype: neuroendocrine cell in Brain_Non-Myeloid
# Subsetting celltype: bladder urothelial cell in Brain_Non-Myeloid
# Subsetting celltype: luminal epithelial cell of mammary gland in Brain_Non-Myeloid
# Subsetting celltype: lung endothelial cell in Brain_Non-Myeloid
# Subsetting celltype: cardiac muscle cell in Brain_Non-Myeloid
# Subsetting celltype: unassigned in Brain_Non-Myeloid
# Subsetting celltype: B cell in Brain_Non-Myeloid
# Subsetting celltype: kidney collecting duct epithelial cell in Brain_Non-Myeloid
# Subsetting tissue: Tongue
# Subsetting celltype: basal cell of epidermis in Tongue
# Subsetting celltype: keratinocyte in Tongue
# Subsetting celltype: unassigned in Tongue
# Subsetting celltype: epithelial cell in Tongue
# Subsetting tissue: Fat
# Subsetting celltype: basophil in Fat
# Subsetting celltype: classical monocyte in Fat
# Subsetting celltype: endocardial cell in Fat
# Subsetting celltype: bladder cell in Fat
# Subsetting celltype: myeloid cell in Fat
# Subsetting celltype: granulocyte in Fat
# Subsetting celltype: ciliated columnar cell of tracheobronchial tree in Fat
# Subsetting celltype: epithelial cell in Fat
# Subsetting celltype: basal cell of epidermis in Fat
# Subsetting celltype: Langerhans cell in Fat
# Subsetting celltype: immature B cell in Fat
# Subsetting celltype: mesangial cell in Fat
# Subsetting celltype: kidney capillary endothelial cell in Fat
# Subsetting celltype: non-classical monocyte in Fat
# Subsetting celltype: immature T cell in Fat
# Subsetting celltype: fibroblast in Fat
# Subsetting celltype: DN1 thymic pro-T cell in Fat
# Subsetting celltype: T cell in Fat
# Subsetting celltype: natural killer cell in Fat
# Subsetting celltype: mesenchymal stem cell in Fat
# Subsetting celltype: endothelial cell in Fat
# Subsetting celltype: macrophage in Fat
# Subsetting celltype: erythroblast in Fat
# Subsetting celltype: hepatocyte in Fat
# Subsetting celltype: stromal cell in Fat
# Subsetting celltype: leukocyte in Fat
# Subsetting celltype: Fraction A pre-pro B cell in Fat
# Subsetting celltype: proerythroblast in Fat
# Subsetting celltype: neuroendocrine cell in Fat
# Subsetting celltype: luminal epithelial cell of mammary gland in Fat
# Subsetting celltype: lung endothelial cell in Fat
# Subsetting celltype: monocyte in Fat
# Subsetting celltype: unassigned in Fat
# Subsetting celltype: B cell in Fat
# Subsetting celltype: dendritic cell in Fat
# Subsetting celltype: kidney collecting duct epithelial cell in Fat
# Subsetting celltype: blood cell in Fat
# Subsetting celltype: kidney cell in Fat
# Subsetting tissue: Mammary_Gland
# Subsetting celltype: basal cell of epidermis in Mammary_Gland
# Subsetting celltype: basophil in Mammary_Gland
# Subsetting celltype: keratinocyte in Mammary_Gland
# Subsetting celltype: endocardial cell in Mammary_Gland
# Subsetting celltype: skeletal muscle satellite cell in Mammary_Gland
# Subsetting celltype: mesangial cell in Mammary_Gland
# Subsetting celltype: bladder cell in Mammary_Gland
# Subsetting celltype: hematopoietic precursor cell in Mammary_Gland
# Subsetting celltype: myeloid cell in Mammary_Gland
# Subsetting celltype: late pro-B cell in Mammary_Gland
# Subsetting celltype: neuroendocrine cell in Mammary_Gland
# Subsetting celltype: luminal epithelial cell of mammary gland in Mammary_Gland
# Subsetting celltype: mesenchymal stem cell in Mammary_Gland
# Subsetting celltype: mast cell in Mammary_Gland
# Subsetting celltype: unassigned in Mammary_Gland
# Subsetting celltype: endothelial cell in Mammary_Gland
# Subsetting celltype: fibroblast in Mammary_Gland
# Subsetting celltype: basal cell in Mammary_Gland
# Subsetting tissue: Limb_Muscle
# Subsetting celltype: basophil in Limb_Muscle
# Subsetting celltype: classical monocyte in Limb_Muscle
# Subsetting celltype: skeletal muscle satellite cell in Limb_Muscle
# Subsetting celltype: endocardial cell in Limb_Muscle
# Subsetting celltype: bladder cell in Limb_Muscle
# Subsetting celltype: myeloid cell in Limb_Muscle
# Subsetting celltype: granulocyte in Limb_Muscle
# Subsetting celltype: basal cell of epidermis in Limb_Muscle
# Subsetting celltype: Langerhans cell in Limb_Muscle
# Subsetting celltype: immature B cell in Limb_Muscle
# Subsetting celltype: mesangial cell in Limb_Muscle
# Subsetting celltype: kidney capillary endothelial cell in Limb_Muscle
# Subsetting celltype: non-classical monocyte in Limb_Muscle
# Subsetting celltype: immature T cell in Limb_Muscle
# Subsetting celltype: fibroblast in Limb_Muscle
# Subsetting celltype: DN1 thymic pro-T cell in Limb_Muscle
# Subsetting celltype: T cell in Limb_Muscle
# Subsetting celltype: mesenchymal stem cell in Limb_Muscle
# Subsetting celltype: natural killer cell in Limb_Muscle
# Subsetting celltype: endothelial cell in Limb_Muscle
# Subsetting celltype: macrophage in Limb_Muscle
# Subsetting celltype: stromal cell in Limb_Muscle
# Subsetting celltype: leukocyte in Limb_Muscle
# Subsetting celltype: Fraction A pre-pro B cell in Limb_Muscle
# Subsetting celltype: neuroendocrine cell in Limb_Muscle
# Subsetting celltype: lung endothelial cell in Limb_Muscle
# Subsetting celltype: unassigned in Limb_Muscle
# Subsetting celltype: B cell in Limb_Muscle
# Subsetting celltype: dendritic cell in Limb_Muscle
# Subsetting celltype: blood cell in Limb_Muscle
# Subsetting celltype: kidney cell in Limb_Muscle
# Subsetting tissue: Trachea
# Subsetting celltype: basophil in Trachea
# Subsetting celltype: classical monocyte in Trachea
# Subsetting celltype: skeletal muscle satellite cell in Trachea
# Subsetting celltype: endocardial cell in Trachea
# Subsetting celltype: bladder cell in Trachea
# Subsetting celltype: myeloid cell in Trachea
# Subsetting celltype: granulocyte in Trachea
# Subsetting celltype: ciliated columnar cell of tracheobronchial tree in Trachea
# Subsetting celltype: epithelial cell in Trachea
# Subsetting celltype: mesenchymal cell in Trachea
# Subsetting celltype: Langerhans cell in Trachea
# Subsetting celltype: immature B cell in Trachea
# Subsetting celltype: mesangial cell in Trachea
# Subsetting celltype: kidney capillary endothelial cell in Trachea
# Subsetting celltype: hematopoietic precursor cell in Trachea
# Subsetting celltype: non-classical monocyte in Trachea
# Subsetting celltype: immature T cell in Trachea
# Subsetting celltype: fibroblast in Trachea
# Subsetting celltype: DN1 thymic pro-T cell in Trachea
# Subsetting celltype: T cell in Trachea
# Subsetting celltype: mesenchymal stem cell in Trachea
# Subsetting celltype: natural killer cell in Trachea
# Subsetting celltype: endothelial cell in Trachea
# Subsetting celltype: stromal cell in Trachea
# Subsetting celltype: leukocyte in Trachea
# Subsetting celltype: Fraction A pre-pro B cell in Trachea
# Subsetting celltype: proerythroblast in Trachea
# Subsetting celltype: neuroendocrine cell in Trachea
# Subsetting celltype: cardiac muscle cell in Trachea
# Subsetting celltype: luminal epithelial cell of mammary gland in Trachea
# Subsetting celltype: unassigned in Trachea
# Subsetting celltype: dendritic cell in Trachea
# Subsetting celltype: kidney collecting duct epithelial cell in Trachea
# Subsetting celltype: blood cell in Trachea
# Subsetting celltype: kidney cell in Trachea
# Subsetting tissue: Lung
# Subsetting celltype: classical monocyte in Lung
# Subsetting celltype: endocardial cell in Lung
# Subsetting celltype: bladder cell in Lung
# Subsetting celltype: myeloid cell in Lung
# Subsetting celltype: ciliated columnar cell of tracheobronchial tree in Lung
# Subsetting celltype: epithelial cell in Lung
# Subsetting celltype: Langerhans cell in Lung
# Subsetting celltype: mesenchymal cell in Lung
# Subsetting celltype: immature B cell in Lung
# Subsetting celltype: mesangial cell in Lung
# Subsetting celltype: kidney capillary endothelial cell in Lung
# Subsetting celltype: non-classical monocyte in Lung
# Subsetting celltype: type II pneumocyte in Lung
# Subsetting celltype: fibroblast in Lung
# Subsetting celltype: DN1 thymic pro-T cell in Lung
# Subsetting celltype: T cell in Lung
# Subsetting celltype: mesenchymal stem cell in Lung
# Subsetting celltype: natural killer cell in Lung
# Subsetting celltype: mast cell in Lung
# Subsetting celltype: endothelial cell in Lung
# Subsetting celltype: erythroblast in Lung
# Subsetting celltype: early pro-B cell in Lung
# Subsetting celltype: stromal cell in Lung
# Subsetting celltype: leukocyte in Lung
# Subsetting celltype: alveolar macrophage in Lung
# Subsetting celltype: proerythroblast in Lung
# Subsetting celltype: neuroendocrine cell in Lung
# Subsetting celltype: lung endothelial cell in Lung
# Subsetting celltype: luminal epithelial cell of mammary gland in Lung
# Subsetting celltype: monocyte in Lung
# Subsetting celltype: unassigned in Lung
# Subsetting celltype: B cell in Lung
# Subsetting celltype: dendritic cell in Lung
# Subsetting celltype: blood cell in Lung
# Subsetting celltype: kidney cell in Lung
# Subsetting tissue: Liver
# Subsetting celltype: endothelial cell of hepatic sinusoid in Liver
# Subsetting celltype: classical monocyte in Liver
# Subsetting celltype: immature B cell in Liver
# Subsetting celltype: Fraction A pre-pro B cell in Liver
# Subsetting celltype: myeloid cell in Liver
# Subsetting celltype: bladder urothelial cell in Liver
# Subsetting celltype: T cell in Liver
# Subsetting celltype: lung endothelial cell in Liver
# Subsetting celltype: natural killer cell in Liver
# Subsetting celltype: granulocyte in Liver
# Subsetting celltype: non-classical monocyte in Liver
# Subsetting celltype: unassigned in Liver
# Subsetting celltype: endothelial cell in Liver
# Subsetting celltype: B cell in Liver
# Subsetting celltype: dendritic cell in Liver
# Subsetting celltype: macrophage in Liver
# Subsetting celltype: hepatocyte in Liver
# Subsetting celltype: blood cell in Liver
# Subsetting celltype: DN1 thymic pro-T cell in Liver
# Subsetting tissue: Spleen
# Subsetting celltype: basophil in Spleen
# Subsetting celltype: classical monocyte in Spleen
# Subsetting celltype: myeloid cell in Spleen
# Subsetting celltype: granulocyte in Spleen
# Subsetting celltype: Langerhans cell in Spleen
# Subsetting celltype: immature B cell in Spleen
# Subsetting celltype: hematopoietic precursor cell in Spleen
# Subsetting celltype: non-classical monocyte in Spleen
# Subsetting celltype: immature T cell in Spleen
# Subsetting celltype: DN1 thymic pro-T cell in Spleen
# Subsetting celltype: late pro-B cell in Spleen
# Subsetting celltype: T cell in Spleen
# Subsetting celltype: natural killer cell in Spleen
# Subsetting celltype: mast cell in Spleen
# Subsetting celltype: macrophage in Spleen
# Subsetting celltype: erythroblast in Spleen
# Subsetting celltype: early pro-B cell in Spleen
# Subsetting celltype: leukocyte in Spleen
# Subsetting celltype: luminal epithelial cell of mammary gland in Spleen
# Subsetting celltype: unassigned in Spleen
# Subsetting celltype: B cell in Spleen
# Subsetting celltype: dendritic cell in Spleen
# Subsetting celltype: kidney cell in Spleen
# Subsetting tissue: Thymus
# Subsetting celltype: Langerhans cell in Thymus
# Subsetting celltype: immature B cell in Thymus
# Subsetting celltype: granulocytopoietic cell in Thymus
# Subsetting celltype: myeloid cell in Thymus
# Subsetting celltype: T cell in Thymus
# Subsetting celltype: natural killer cell in Thymus
# Subsetting celltype: kidney cell in Thymus
# Subsetting celltype: lung endothelial cell in Thymus
# Subsetting celltype: non-classical monocyte in Thymus
# Subsetting celltype: blood cell in Thymus
# Subsetting celltype: unassigned in Thymus
# Subsetting celltype: endothelial cell in Thymus
# Subsetting celltype: B cell in Thymus
# Subsetting celltype: dendritic cell in Thymus
# Subsetting celltype: macrophage in Thymus
# Subsetting celltype: immature T cell in Thymus
# Subsetting celltype: fibroblast in Thymus
# Subsetting celltype: DN1 thymic pro-T cell in Thymus
# Subsetting celltype: basal cell in Thymus
# Subsetting celltype: epithelial cell in Thymus
# Subsetting tissue: Skin
# Subsetting celltype: basal cell of epidermis in Skin
# Subsetting celltype: keratinocyte in Skin
# Subsetting celltype: classical monocyte in Skin
# Subsetting celltype: neuroendocrine cell in Skin
# Subsetting celltype: mesenchymal stem cell in Skin
# Subsetting celltype: unassigned in Skin
# Subsetting celltype: endothelial cell in Skin
# Subsetting celltype: basal cell in Skin
# Subsetting tissue: Bladder
# Subsetting celltype: skeletal muscle satellite cell in Bladder
# Subsetting celltype: bladder cell in Bladder
# Subsetting celltype: bladder urothelial cell in Bladder
# Subsetting celltype: neuroendocrine cell in Bladder
# Subsetting celltype: mesenchymal stem cell in Bladder
# Subsetting celltype: lung endothelial cell in Bladder
# Subsetting celltype: unassigned in Bladder
# Subsetting celltype: endothelial cell in Bladder
# Subsetting celltype: fibroblast in Bladder
# Subsetting celltype: basal cell in Bladder
# Subsetting tissue: Heart
# Subsetting celltype: classical monocyte in Heart
# Subsetting celltype: endocardial cell in Heart
# Subsetting celltype: skeletal muscle satellite cell in Heart
# Subsetting celltype: bladder cell in Heart
# Subsetting celltype: myeloid cell in Heart
# Subsetting celltype: granulocyte in Heart
# Subsetting celltype: epithelial cell in Heart
# Subsetting celltype: basal cell of epidermis in Heart
# Subsetting celltype: Langerhans cell in Heart
# Subsetting celltype: mesenchymal cell in Heart
# Subsetting celltype: immature B cell in Heart
# Subsetting celltype: mesangial cell in Heart
# Subsetting celltype: kidney capillary endothelial cell in Heart
# Subsetting celltype: non-classical monocyte in Heart
# Subsetting celltype: immature T cell in Heart
# Subsetting celltype: fibroblast in Heart
# Subsetting celltype: DN1 thymic pro-T cell in Heart
# Subsetting celltype: T cell in Heart
# Subsetting celltype: natural killer cell in Heart
# Subsetting celltype: mesenchymal stem cell in Heart
# Subsetting celltype: endothelial cell in Heart
# Subsetting celltype: macrophage in Heart
# Subsetting celltype: erythroblast in Heart
# Subsetting celltype: hepatocyte in Heart
# Subsetting celltype: stromal cell in Heart
# Subsetting celltype: basal cell in Heart
# Subsetting celltype: leukocyte in Heart
# Subsetting celltype: alveolar macrophage in Heart
# Subsetting celltype: proerythroblast in Heart
# Subsetting celltype: neuroendocrine cell in Heart
# Subsetting celltype: cardiac muscle cell in Heart
# Subsetting celltype: lung endothelial cell in Heart
# Subsetting celltype: bladder urothelial cell in Heart
# Subsetting celltype: unassigned in Heart
# Subsetting celltype: B cell in Heart
# Subsetting celltype: dendritic cell in Heart
# Subsetting celltype: blood cell in Heart
# Subsetting celltype: kidney cell in Heart
# Subsetting tissue: Marrow
# Subsetting celltype: basophil in Marrow
# Subsetting celltype: classical monocyte in Marrow
# Subsetting celltype: bladder cell in Marrow
# Subsetting celltype: myeloid cell in Marrow
# Subsetting celltype: granulocyte in Marrow
# Subsetting celltype: immature B cell in Marrow
# Subsetting celltype: granulocytopoietic cell in Marrow
# Subsetting celltype: hematopoietic precursor cell in Marrow
# Subsetting celltype: non-classical monocyte in Marrow
# Subsetting celltype: DN1 thymic pro-T cell in Marrow
# Subsetting celltype: late pro-B cell in Marrow
# Subsetting celltype: promonocyte in Marrow
# Subsetting celltype: natural killer cell in Marrow
# Subsetting celltype: T cell in Marrow
# Subsetting celltype: mast cell in Marrow
# Subsetting celltype: macrophage in Marrow
# Subsetting celltype: early pro-B cell in Marrow
# Subsetting celltype: leukocyte in Marrow
# Subsetting celltype: Fraction A pre-pro B cell in Marrow
# Subsetting celltype: alveolar macrophage in Marrow
# Subsetting celltype: proerythroblast in Marrow
# Subsetting celltype: monocyte in Marrow
# Subsetting celltype: unassigned in Marrow
# Subsetting celltype: B cell in Marrow
# Subsetting celltype: dendritic cell in Marrow
# Subsetting celltype: kidney cell in Marrow
# Subsetting tissue: Kidney
# Subsetting celltype: classical monocyte in Kidney
# Subsetting celltype: bladder cell in Kidney
# Subsetting celltype: myeloid cell in Kidney
# Subsetting celltype: kidney loop of Henle ascending limb epithelial cell in Kidney
# Subsetting celltype: epithelial cell in Kidney
# Subsetting celltype: immature B cell in Kidney
# Subsetting celltype: mesangial cell in Kidney
# Subsetting celltype: kidney capillary endothelial cell in Kidney
# Subsetting celltype: non-classical monocyte in Kidney
# Subsetting celltype: fibroblast in Kidney
# Subsetting celltype: DN1 thymic pro-T cell in Kidney
# Subsetting celltype: T cell in Kidney
# Subsetting celltype: mesenchymal stem cell in Kidney
# Subsetting celltype: natural killer cell in Kidney
# Subsetting celltype: endothelial cell in Kidney
# Subsetting celltype: macrophage in Kidney
# Subsetting celltype: stromal cell in Kidney
# Subsetting celltype: kidney proximal straight tubule epithelial cell in Kidney
# Subsetting celltype: neuroendocrine cell in Kidney
# Subsetting celltype: bladder urothelial cell in Kidney
# Subsetting celltype: unassigned in Kidney
# Subsetting celltype: B cell in Kidney
# Subsetting celltype: kidney collecting duct epithelial cell in Kidney
# Subsetting celltype: blood cell in Kidney
# Subsetting celltype: kidney cell in Kidney

# %%
facs
# Out:
# AnnData object with n_obs × n_vars = 2571 × 23433
#     obs: 'celltype'

# %%
## 20 cell pseudobulk from MCA
mca = pseudobulk(mca, 'tissue', 'from_droplet', n_cells)
# Out:
# Subsetting tissue: Uterus
# Subsetting celltype: unassigned in Uterus
# Subsetting celltype: skeletal muscle satellite cell in Uterus
# Subsetting celltype: T cell in Uterus
# Subsetting celltype: macrophage in Uterus
# Subsetting tissue: Stomach
# Subsetting celltype: classical monocyte in Stomach
# Subsetting celltype: skeletal muscle satellite cell in Stomach
# Subsetting celltype: endocardial cell in Stomach
# Subsetting celltype: bladder cell in Stomach
# Subsetting celltype: epithelial cell in Stomach
# Subsetting celltype: mesenchymal cell in Stomach
# Subsetting celltype: mesangial cell in Stomach
# Subsetting celltype: hematopoietic precursor cell in Stomach
# Subsetting celltype: fibroblast in Stomach
# Subsetting celltype: DN1 thymic pro-T cell in Stomach
# Subsetting celltype: late pro-B cell in Stomach
# Subsetting celltype: T cell in Stomach
# Subsetting celltype: endothelial cell in Stomach
# Subsetting celltype: macrophage in Stomach
# Subsetting celltype: stromal cell in Stomach
# Subsetting celltype: basal cell in Stomach
# Subsetting celltype: neuroendocrine cell in Stomach
# Subsetting celltype: cardiac muscle cell in Stomach
# Subsetting celltype: luminal epithelial cell of mammary gland in Stomach
# Subsetting celltype: bladder urothelial cell in Stomach
# Subsetting celltype: unassigned in Stomach
# Subsetting celltype: kidney collecting duct epithelial cell in Stomach
# Subsetting celltype: kidney cell in Stomach
# Subsetting tissue: Neonatal-Muscle
# Subsetting celltype: skeletal muscle satellite cell in Neonatal-Muscle
# Subsetting celltype: bladder cell in Neonatal-Muscle
# Subsetting celltype: myeloid cell in Neonatal-Muscle
# Subsetting celltype: Langerhans cell in Neonatal-Muscle
# Subsetting celltype: mesenchymal cell in Neonatal-Muscle
# Subsetting celltype: immature B cell in Neonatal-Muscle
# Subsetting celltype: hematopoietic precursor cell in Neonatal-Muscle
# Subsetting celltype: non-classical monocyte in Neonatal-Muscle
# Subsetting celltype: fibroblast in Neonatal-Muscle
# Subsetting celltype: DN1 thymic pro-T cell in Neonatal-Muscle
# Subsetting celltype: T cell in Neonatal-Muscle
# Subsetting celltype: mesenchymal stem cell in Neonatal-Muscle
# Subsetting celltype: natural killer cell in Neonatal-Muscle
# Subsetting celltype: promonocyte in Neonatal-Muscle
# Subsetting celltype: macrophage in Neonatal-Muscle
# Subsetting celltype: basal cell in Neonatal-Muscle
# Subsetting celltype: leukocyte in Neonatal-Muscle
# Subsetting celltype: neuroendocrine cell in Neonatal-Muscle
# Subsetting celltype: bladder urothelial cell in Neonatal-Muscle
# Subsetting celltype: luminal epithelial cell of mammary gland in Neonatal-Muscle
# Subsetting celltype: unassigned in Neonatal-Muscle
# Subsetting celltype: B cell in Neonatal-Muscle
# Subsetting celltype: dendritic cell in Neonatal-Muscle
# Subsetting celltype: blood cell in Neonatal-Muscle
# Subsetting celltype: kidney cell in Neonatal-Muscle
# Subsetting tissue: Neonatal-Rib
# Subsetting celltype: basophil in Neonatal-Rib
# Subsetting celltype: skeletal muscle satellite cell in Neonatal-Rib
# Subsetting celltype: bladder cell in Neonatal-Rib
# Subsetting celltype: granulocyte in Neonatal-Rib
# Subsetting celltype: mesenchymal cell in Neonatal-Rib
# Subsetting celltype: granulocytopoietic cell in Neonatal-Rib
# Subsetting celltype: kidney capillary endothelial cell in Neonatal-Rib
# Subsetting celltype: hematopoietic precursor cell in Neonatal-Rib
# Subsetting celltype: DN1 thymic pro-T cell in Neonatal-Rib
# Subsetting celltype: late pro-B cell in Neonatal-Rib
# Subsetting celltype: promonocyte in Neonatal-Rib
# Subsetting celltype: T cell in Neonatal-Rib
# Subsetting celltype: mesenchymal stem cell in Neonatal-Rib
# Subsetting celltype: endothelial cell in Neonatal-Rib
# Subsetting celltype: erythroblast in Neonatal-Rib
# Subsetting celltype: early pro-B cell in Neonatal-Rib
# Subsetting celltype: basal cell in Neonatal-Rib
# Subsetting celltype: proerythroblast in Neonatal-Rib
# Subsetting celltype: bladder urothelial cell in Neonatal-Rib
# Subsetting celltype: neuroendocrine cell in Neonatal-Rib
# Subsetting celltype: luminal epithelial cell of mammary gland in Neonatal-Rib
# Subsetting celltype: unassigned in Neonatal-Rib
# Subsetting tissue: Neonatal-Heart
# Subsetting celltype: classical monocyte in Neonatal-Heart
# Subsetting celltype: bladder cell in Neonatal-Heart
# Subsetting celltype: myeloid cell in Neonatal-Heart
# Subsetting celltype: Langerhans cell in Neonatal-Heart
# Subsetting celltype: immature B cell in Neonatal-Heart
# Subsetting celltype: hematopoietic precursor cell in Neonatal-Heart
# Subsetting celltype: non-classical monocyte in Neonatal-Heart
# Subsetting celltype: immature T cell in Neonatal-Heart
# Subsetting celltype: fibroblast in Neonatal-Heart
# Subsetting celltype: DN1 thymic pro-T cell in Neonatal-Heart
# Subsetting celltype: promonocyte in Neonatal-Heart
# Subsetting celltype: T cell in Neonatal-Heart
# Subsetting celltype: mesenchymal stem cell in Neonatal-Heart
# Subsetting celltype: natural killer cell in Neonatal-Heart
# Subsetting celltype: macrophage in Neonatal-Heart
# Subsetting celltype: early pro-B cell in Neonatal-Heart
# Subsetting celltype: leukocyte in Neonatal-Heart
# Subsetting celltype: Fraction A pre-pro B cell in Neonatal-Heart
# Subsetting celltype: luminal epithelial cell of mammary gland in Neonatal-Heart
# Subsetting celltype: unassigned in Neonatal-Heart
# Subsetting celltype: B cell in Neonatal-Heart
# Subsetting celltype: dendritic cell in Neonatal-Heart
# Subsetting celltype: blood cell in Neonatal-Heart
# Subsetting celltype: kidney cell in Neonatal-Heart
# Subsetting tissue: Neonatal-Skin
# Subsetting celltype: basophil in Neonatal-Skin
# Subsetting celltype: skeletal muscle satellite cell in Neonatal-Skin
# Subsetting celltype: endocardial cell in Neonatal-Skin
# Subsetting celltype: bladder cell in Neonatal-Skin
# Subsetting celltype: granulocyte in Neonatal-Skin
# Subsetting celltype: mesenchymal cell in Neonatal-Skin
# Subsetting celltype: immature B cell in Neonatal-Skin
# Subsetting celltype: mesangial cell in Neonatal-Skin
# Subsetting celltype: granulocytopoietic cell in Neonatal-Skin
# Subsetting celltype: kidney capillary endothelial cell in Neonatal-Skin
# Subsetting celltype: hematopoietic precursor cell in Neonatal-Skin
# Subsetting celltype: late pro-B cell in Neonatal-Skin
# Subsetting celltype: T cell in Neonatal-Skin
# Subsetting celltype: mesenchymal stem cell in Neonatal-Skin
# Subsetting celltype: promonocyte in Neonatal-Skin
# Subsetting celltype: mast cell in Neonatal-Skin
# Subsetting celltype: endothelial cell in Neonatal-Skin
# Subsetting celltype: early pro-B cell in Neonatal-Skin
# Subsetting celltype: proerythroblast in Neonatal-Skin
# Subsetting celltype: neuroendocrine cell in Neonatal-Skin
# Subsetting celltype: lung endothelial cell in Neonatal-Skin
# Subsetting celltype: monocyte in Neonatal-Skin
# Subsetting celltype: unassigned in Neonatal-Skin
# Subsetting tissue: Bone-Marrow
# Subsetting celltype: hematopoietic precursor cell in Bone-Marrow
# Subsetting celltype: unassigned in Bone-Marrow
# Subsetting celltype: skeletal muscle satellite cell in Bone-Marrow
# Subsetting celltype: T cell in Bone-Marrow
# Subsetting tissue: Brain
# Subsetting celltype: skeletal muscle satellite cell in Brain
# Subsetting celltype: hematopoietic precursor cell in Brain
# Subsetting celltype: T cell in Brain
# Subsetting celltype: luminal epithelial cell of mammary gland in Brain
# Subsetting celltype: unassigned in Brain
# Subsetting tissue: Trophoblast-Stem-Cell
# Subsetting celltype: basophil in Trophoblast-Stem-Cell
# Subsetting celltype: classical monocyte in Trophoblast-Stem-Cell
# Subsetting celltype: skeletal muscle satellite cell in Trophoblast-Stem-Cell
# Subsetting celltype: duct epithelial cell in Trophoblast-Stem-Cell
# Subsetting celltype: bladder cell in Trophoblast-Stem-Cell
# Subsetting celltype: myeloid cell in Trophoblast-Stem-Cell
# Subsetting celltype: granulocyte in Trophoblast-Stem-Cell
# Subsetting celltype: epithelial cell in Trophoblast-Stem-Cell
# Subsetting celltype: basal cell of epidermis in Trophoblast-Stem-Cell
# Subsetting celltype: Langerhans cell in Trophoblast-Stem-Cell
# Subsetting celltype: immature B cell in Trophoblast-Stem-Cell
# Subsetting celltype: granulocytopoietic cell in Trophoblast-Stem-Cell
# Subsetting celltype: hematopoietic precursor cell in Trophoblast-Stem-Cell
# Subsetting celltype: non-classical monocyte in Trophoblast-Stem-Cell
# Subsetting celltype: immature T cell in Trophoblast-Stem-Cell
# Subsetting celltype: fibroblast in Trophoblast-Stem-Cell
# Subsetting celltype: DN1 thymic pro-T cell in Trophoblast-Stem-Cell
# Subsetting celltype: T cell in Trophoblast-Stem-Cell
# Subsetting celltype: natural killer cell in Trophoblast-Stem-Cell
# Subsetting celltype: promonocyte in Trophoblast-Stem-Cell
# Subsetting celltype: mesenchymal stem cell in Trophoblast-Stem-Cell
# Subsetting celltype: macrophage in Trophoblast-Stem-Cell
# Subsetting celltype: basal cell in Trophoblast-Stem-Cell
# Subsetting celltype: leukocyte in Trophoblast-Stem-Cell
# Subsetting celltype: Fraction A pre-pro B cell in Trophoblast-Stem-Cell
# Subsetting celltype: alveolar macrophage in Trophoblast-Stem-Cell
# Subsetting celltype: bladder urothelial cell in Trophoblast-Stem-Cell
# Subsetting celltype: cardiac muscle cell in Trophoblast-Stem-Cell
# Subsetting celltype: luminal epithelial cell of mammary gland in Trophoblast-Stem-Cell
# Subsetting celltype: monocyte in Trophoblast-Stem-Cell
# Subsetting celltype: unassigned in Trophoblast-Stem-Cell
# Subsetting celltype: dendritic cell in Trophoblast-Stem-Cell
# Subsetting celltype: B cell in Trophoblast-Stem-Cell
# Subsetting celltype: kidney collecting duct epithelial cell in Trophoblast-Stem-Cell
# Subsetting celltype: blood cell in Trophoblast-Stem-Cell
# Subsetting celltype: kidney cell in Trophoblast-Stem-Cell
# Subsetting tissue: Fetal_Kidney
# Subsetting celltype: unassigned in Fetal_Kidney
# Subsetting tissue: MammaryGland.Pregnancy
# Subsetting celltype: skeletal muscle satellite cell in MammaryGland.Pregnancy
# Subsetting celltype: hematopoietic precursor cell in MammaryGland.Pregnancy
# Subsetting celltype: bladder urothelial cell in MammaryGland.Pregnancy
# Subsetting celltype: T cell in MammaryGland.Pregnancy
# Subsetting celltype: luminal epithelial cell of mammary gland in MammaryGland.Pregnancy
# Subsetting celltype: unassigned in MammaryGland.Pregnancy
# Subsetting celltype: immature T cell in MammaryGland.Pregnancy
# Subsetting celltype: DN1 thymic pro-T cell in MammaryGland.Pregnancy
# Subsetting celltype: basal cell in MammaryGland.Pregnancy
# Subsetting tissue: Bone-Marrow_c-kit
# Subsetting celltype: basophil in Bone-Marrow_c-kit
# Subsetting celltype: classical monocyte in Bone-Marrow_c-kit
# Subsetting celltype: skeletal muscle satellite cell in Bone-Marrow_c-kit
# Subsetting celltype: myeloid cell in Bone-Marrow_c-kit
# Subsetting celltype: granulocyte in Bone-Marrow_c-kit
# Subsetting celltype: immature B cell in Bone-Marrow_c-kit
# Subsetting celltype: granulocytopoietic cell in Bone-Marrow_c-kit
# Subsetting celltype: hematopoietic precursor cell in Bone-Marrow_c-kit
# Subsetting celltype: non-classical monocyte in Bone-Marrow_c-kit
# Subsetting celltype: DN1 thymic pro-T cell in Bone-Marrow_c-kit
# Subsetting celltype: late pro-B cell in Bone-Marrow_c-kit
# Subsetting celltype: promonocyte in Bone-Marrow_c-kit
# Subsetting celltype: natural killer cell in Bone-Marrow_c-kit
# Subsetting celltype: T cell in Bone-Marrow_c-kit
# Subsetting celltype: mast cell in Bone-Marrow_c-kit
# Subsetting celltype: endothelial cell in Bone-Marrow_c-kit
# Subsetting celltype: macrophage in Bone-Marrow_c-kit
# Subsetting celltype: erythroblast in Bone-Marrow_c-kit
# Subsetting celltype: early pro-B cell in Bone-Marrow_c-kit
# Subsetting celltype: Fraction A pre-pro B cell in Bone-Marrow_c-kit
# Subsetting celltype: proerythroblast in Bone-Marrow_c-kit
# Subsetting celltype: monocyte in Bone-Marrow_c-kit
# Subsetting celltype: unassigned in Bone-Marrow_c-kit
# Subsetting celltype: dendritic cell in Bone-Marrow_c-kit
# Subsetting celltype: blood cell in Bone-Marrow_c-kit
# Subsetting celltype: kidney cell in Bone-Marrow_c-kit
# Subsetting tissue: Peripheral_Blood
# Subsetting celltype: basophil in Peripheral_Blood
# Subsetting celltype: classical monocyte in Peripheral_Blood
# Subsetting celltype: skeletal muscle satellite cell in Peripheral_Blood
# Subsetting celltype: endocardial cell in Peripheral_Blood
# Subsetting celltype: bladder cell in Peripheral_Blood
# Subsetting celltype: myeloid cell in Peripheral_Blood
# Subsetting celltype: granulocyte in Peripheral_Blood
# Subsetting celltype: mesenchymal cell in Peripheral_Blood
# Subsetting celltype: immature B cell in Peripheral_Blood
# Subsetting celltype: mesangial cell in Peripheral_Blood
# Subsetting celltype: granulocytopoietic cell in Peripheral_Blood
# Subsetting celltype: hematopoietic precursor cell in Peripheral_Blood
# Subsetting celltype: non-classical monocyte in Peripheral_Blood
# Subsetting celltype: fibroblast in Peripheral_Blood
# Subsetting celltype: late pro-B cell in Peripheral_Blood
# Subsetting celltype: T cell in Peripheral_Blood
# Subsetting celltype: mesenchymal stem cell in Peripheral_Blood
# Subsetting celltype: promonocyte in Peripheral_Blood
# Subsetting celltype: natural killer cell in Peripheral_Blood
# Subsetting celltype: mast cell in Peripheral_Blood
# Subsetting celltype: endothelial cell in Peripheral_Blood
# Subsetting celltype: macrophage in Peripheral_Blood
# Subsetting celltype: erythroblast in Peripheral_Blood
# Subsetting celltype: early pro-B cell in Peripheral_Blood
# Subsetting celltype: stromal cell in Peripheral_Blood
# Subsetting celltype: basal cell in Peripheral_Blood
# Subsetting celltype: leukocyte in Peripheral_Blood
# Subsetting celltype: Fraction A pre-pro B cell in Peripheral_Blood
# Subsetting celltype: alveolar macrophage in Peripheral_Blood
# Subsetting celltype: neuroendocrine cell in Peripheral_Blood
# Subsetting celltype: cardiac muscle cell in Peripheral_Blood
# Subsetting celltype: lung endothelial cell in Peripheral_Blood
# Subsetting celltype: monocyte in Peripheral_Blood
# Subsetting celltype: unassigned in Peripheral_Blood
# Subsetting celltype: kidney cell in Peripheral_Blood
# Subsetting tissue: MammaryGland.Lactation
# Subsetting celltype: mesenchymal cell in MammaryGland.Lactation
# Subsetting celltype: skeletal muscle satellite cell in MammaryGland.Lactation
# Subsetting celltype: hematopoietic precursor cell in MammaryGland.Lactation
# Subsetting celltype: alveolar macrophage in MammaryGland.Lactation
# Subsetting celltype: neuroendocrine cell in MammaryGland.Lactation
# Subsetting celltype: T cell in MammaryGland.Lactation
# Subsetting celltype: luminal epithelial cell of mammary gland in MammaryGland.Lactation
# Subsetting celltype: promonocyte in MammaryGland.Lactation
# Subsetting celltype: bladder urothelial cell in MammaryGland.Lactation
# Subsetting celltype: monocyte in MammaryGland.Lactation
# Subsetting celltype: unassigned in MammaryGland.Lactation
# Subsetting celltype: immature T cell in MammaryGland.Lactation
# Subsetting celltype: DN1 thymic pro-T cell in MammaryGland.Lactation
# Subsetting celltype: basal cell in MammaryGland.Lactation
# Subsetting tissue: Neonatal-Calvaria
# Subsetting celltype: classical monocyte in Neonatal-Calvaria
# Subsetting celltype: bladder cell in Neonatal-Calvaria
# Subsetting celltype: myeloid cell in Neonatal-Calvaria
# Subsetting celltype: granulocyte in Neonatal-Calvaria
# Subsetting celltype: Langerhans cell in Neonatal-Calvaria
# Subsetting celltype: immature B cell in Neonatal-Calvaria
# Subsetting celltype: hematopoietic precursor cell in Neonatal-Calvaria
# Subsetting celltype: non-classical monocyte in Neonatal-Calvaria
# Subsetting celltype: fibroblast in Neonatal-Calvaria
# Subsetting celltype: DN1 thymic pro-T cell in Neonatal-Calvaria
# Subsetting celltype: T cell in Neonatal-Calvaria
# Subsetting celltype: natural killer cell in Neonatal-Calvaria
# Subsetting celltype: mesenchymal stem cell in Neonatal-Calvaria
# Subsetting celltype: endothelial cell in Neonatal-Calvaria
# Subsetting celltype: macrophage in Neonatal-Calvaria
# Subsetting celltype: basal cell in Neonatal-Calvaria
# Subsetting celltype: leukocyte in Neonatal-Calvaria
# Subsetting celltype: Fraction A pre-pro B cell in Neonatal-Calvaria
# Subsetting celltype: neuroendocrine cell in Neonatal-Calvaria
# Subsetting celltype: luminal epithelial cell of mammary gland in Neonatal-Calvaria
# Subsetting celltype: unassigned in Neonatal-Calvaria
# Subsetting celltype: B cell in Neonatal-Calvaria
# Subsetting celltype: dendritic cell in Neonatal-Calvaria
# Subsetting celltype: blood cell in Neonatal-Calvaria
# Subsetting celltype: kidney cell in Neonatal-Calvaria
# Subsetting tissue: Lung
# Subsetting celltype: basophil in Lung
# Subsetting celltype: classical monocyte in Lung
# Subsetting celltype: skeletal muscle satellite cell in Lung
# Subsetting celltype: bladder cell in Lung
# Subsetting celltype: myeloid cell in Lung
# Subsetting celltype: Langerhans cell in Lung
# Subsetting celltype: immature B cell in Lung
# Subsetting celltype: hematopoietic precursor cell in Lung
# Subsetting celltype: non-classical monocyte in Lung
# Subsetting celltype: immature T cell in Lung
# Subsetting celltype: fibroblast in Lung
# Subsetting celltype: DN1 thymic pro-T cell in Lung
# Subsetting celltype: T cell in Lung
# Subsetting celltype: mesenchymal stem cell in Lung
# Subsetting celltype: natural killer cell in Lung
# Subsetting celltype: endothelial cell in Lung
# Subsetting celltype: macrophage in Lung
# Subsetting celltype: basal cell in Lung
# Subsetting celltype: leukocyte in Lung
# Subsetting celltype: Fraction A pre-pro B cell in Lung
# Subsetting celltype: alveolar macrophage in Lung
# Subsetting celltype: bladder urothelial cell in Lung
# Subsetting celltype: luminal epithelial cell of mammary gland in Lung
# Subsetting celltype: unassigned in Lung
# Subsetting celltype: B cell in Lung
# Subsetting celltype: dendritic cell in Lung
# Subsetting celltype: blood cell in Lung
# Subsetting celltype: kidney cell in Lung
# Subsetting tissue: MammaryGland.Virgin
# Subsetting celltype: basophil in MammaryGland.Virgin
# Subsetting celltype: classical monocyte in MammaryGland.Virgin
# Subsetting celltype: skeletal muscle satellite cell in MammaryGland.Virgin
# Subsetting celltype: duct epithelial cell in MammaryGland.Virgin
# Subsetting celltype: endocardial cell in MammaryGland.Virgin
# Subsetting celltype: bladder cell in MammaryGland.Virgin
# Subsetting celltype: myeloid cell in MammaryGland.Virgin
# Subsetting celltype: epithelial cell in MammaryGland.Virgin
# Subsetting celltype: Langerhans cell in MammaryGland.Virgin
# Subsetting celltype: mesangial cell in MammaryGland.Virgin
# Subsetting celltype: kidney capillary endothelial cell in MammaryGland.Virgin
# Subsetting celltype: hematopoietic precursor cell in MammaryGland.Virgin
# Subsetting celltype: non-classical monocyte in MammaryGland.Virgin
# Subsetting celltype: fibroblast in MammaryGland.Virgin
# Subsetting celltype: DN1 thymic pro-T cell in MammaryGland.Virgin
# Subsetting celltype: T cell in MammaryGland.Virgin
# Subsetting celltype: mesenchymal stem cell in MammaryGland.Virgin
# Subsetting celltype: natural killer cell in MammaryGland.Virgin
# Subsetting celltype: endothelial cell in MammaryGland.Virgin
# Subsetting celltype: macrophage in MammaryGland.Virgin
# Subsetting celltype: basal cell in MammaryGland.Virgin
# Subsetting celltype: stromal cell in MammaryGland.Virgin
# Subsetting celltype: leukocyte in MammaryGland.Virgin
# Subsetting celltype: Fraction A pre-pro B cell in MammaryGland.Virgin
# Subsetting celltype: neuroendocrine cell in MammaryGland.Virgin
# Subsetting celltype: bladder urothelial cell in MammaryGland.Virgin
# Subsetting celltype: luminal epithelial cell of mammary gland in MammaryGland.Virgin
# Subsetting celltype: lung endothelial cell in MammaryGland.Virgin
# Subsetting celltype: unassigned in MammaryGland.Virgin
# Subsetting celltype: dendritic cell in MammaryGland.Virgin
# Subsetting celltype: blood cell in MammaryGland.Virgin
# Subsetting celltype: kidney cell in MammaryGland.Virgin
# Subsetting tissue: Fetal_Brain
# Subsetting celltype: basophil in Fetal_Brain
# Subsetting celltype: classical monocyte in Fetal_Brain
# Subsetting celltype: skeletal muscle satellite cell in Fetal_Brain
# Subsetting celltype: endocardial cell in Fetal_Brain
# Subsetting celltype: bladder cell in Fetal_Brain
# Subsetting celltype: myeloid cell in Fetal_Brain
# Subsetting celltype: granulocyte in Fetal_Brain
# Subsetting celltype: granulocytopoietic cell in Fetal_Brain
# Subsetting celltype: hematopoietic precursor cell in Fetal_Brain
# Subsetting celltype: non-classical monocyte in Fetal_Brain
# Subsetting celltype: immature T cell in Fetal_Brain
# Subsetting celltype: fibroblast in Fetal_Brain
# Subsetting celltype: DN1 thymic pro-T cell in Fetal_Brain
# Subsetting celltype: late pro-B cell in Fetal_Brain
# Subsetting celltype: T cell in Fetal_Brain
# Subsetting celltype: promonocyte in Fetal_Brain
# Subsetting celltype: natural killer cell in Fetal_Brain
# Subsetting celltype: macrophage in Fetal_Brain
# Subsetting celltype: hepatocyte in Fetal_Brain
# Subsetting celltype: leukocyte in Fetal_Brain
# Subsetting celltype: Fraction A pre-pro B cell in Fetal_Brain
# Subsetting celltype: alveolar macrophage in Fetal_Brain
# Subsetting celltype: proerythroblast in Fetal_Brain
# Subsetting celltype: bladder urothelial cell in Fetal_Brain
# Subsetting celltype: luminal epithelial cell of mammary gland in Fetal_Brain
# Subsetting celltype: monocyte in Fetal_Brain
# Subsetting celltype: unassigned in Fetal_Brain
# Subsetting celltype: kidney cell in Fetal_Brain
# Subsetting tissue: Fetal_Stomache
# Subsetting celltype: basophil in Fetal_Stomache
# Subsetting celltype: classical monocyte in Fetal_Stomache
# Subsetting celltype: skeletal muscle satellite cell in Fetal_Stomache
# Subsetting celltype: bladder cell in Fetal_Stomache
# Subsetting celltype: myeloid cell in Fetal_Stomache
# Subsetting celltype: kidney loop of Henle ascending limb epithelial cell in Fetal_Stomache
# Subsetting celltype: granulocyte in Fetal_Stomache
# Subsetting celltype: Langerhans cell in Fetal_Stomache
# Subsetting celltype: immature B cell in Fetal_Stomache
# Subsetting celltype: granulocytopoietic cell in Fetal_Stomache
# Subsetting celltype: kidney capillary endothelial cell in Fetal_Stomache
# Subsetting celltype: hematopoietic precursor cell in Fetal_Stomache
# Subsetting celltype: non-classical monocyte in Fetal_Stomache
# Subsetting celltype: fibroblast in Fetal_Stomache
# Subsetting celltype: DN1 thymic pro-T cell in Fetal_Stomache
# Subsetting celltype: endothelial cell of hepatic sinusoid in Fetal_Stomache
# Subsetting celltype: promonocyte in Fetal_Stomache
# Subsetting celltype: mesenchymal stem cell in Fetal_Stomache
# Subsetting celltype: natural killer cell in Fetal_Stomache
# Subsetting celltype: T cell in Fetal_Stomache
# Subsetting celltype: endothelial cell in Fetal_Stomache
# Subsetting celltype: macrophage in Fetal_Stomache
# Subsetting celltype: hepatocyte in Fetal_Stomache
# Subsetting celltype: leukocyte in Fetal_Stomache
# Subsetting celltype: kidney proximal straight tubule epithelial cell in Fetal_Stomache
# Subsetting celltype: bladder urothelial cell in Fetal_Stomache
# Subsetting celltype: luminal epithelial cell of mammary gland in Fetal_Stomache
# Subsetting celltype: monocyte in Fetal_Stomache
# Subsetting celltype: unassigned in Fetal_Stomache
# Subsetting celltype: B cell in Fetal_Stomache
# Subsetting celltype: dendritic cell in Fetal_Stomache
# Subsetting celltype: kidney collecting duct epithelial cell in Fetal_Stomache
# Subsetting celltype: blood cell in Fetal_Stomache
# Subsetting celltype: kidney cell in Fetal_Stomache
# Subsetting tissue: Embryonic-Mesenchyme
# Subsetting celltype: skeletal muscle satellite cell in Embryonic-Mesenchyme
# Subsetting celltype: hematopoietic precursor cell in Embryonic-Mesenchyme
# Subsetting celltype: T cell in Embryonic-Mesenchyme
# Subsetting celltype: luminal epithelial cell of mammary gland in Embryonic-Mesenchyme
# Subsetting celltype: unassigned in Embryonic-Mesenchyme
# Subsetting tissue: Small-Intestine
# Subsetting celltype: basophil in Small-Intestine
# Subsetting celltype: classical monocyte in Small-Intestine
# Subsetting celltype: skeletal muscle satellite cell in Small-Intestine
# Subsetting celltype: endocardial cell in Small-Intestine
# Subsetting celltype: bladder cell in Small-Intestine
# Subsetting celltype: myeloid cell in Small-Intestine
# Subsetting celltype: granulocyte in Small-Intestine
# Subsetting celltype: basal cell of epidermis in Small-Intestine
# Subsetting celltype: mesenchymal cell in Small-Intestine
# Subsetting celltype: Langerhans cell in Small-Intestine
# Subsetting celltype: immature B cell in Small-Intestine
# Subsetting celltype: mesangial cell in Small-Intestine
# Subsetting celltype: granulocytopoietic cell in Small-Intestine
# Subsetting celltype: hematopoietic precursor cell in Small-Intestine
# Subsetting celltype: non-classical monocyte in Small-Intestine
# Subsetting celltype: immature T cell in Small-Intestine
# Subsetting celltype: fibroblast in Small-Intestine
# Subsetting celltype: DN1 thymic pro-T cell in Small-Intestine
# Subsetting celltype: late pro-B cell in Small-Intestine
# Subsetting celltype: promonocyte in Small-Intestine
# Subsetting celltype: mesenchymal stem cell in Small-Intestine
# Subsetting celltype: T cell in Small-Intestine
# Subsetting celltype: natural killer cell in Small-Intestine
# Subsetting celltype: mast cell in Small-Intestine
# Subsetting celltype: endothelial cell in Small-Intestine
# Subsetting celltype: macrophage in Small-Intestine
# Subsetting celltype: early pro-B cell in Small-Intestine
# Subsetting celltype: basal cell in Small-Intestine
# Subsetting celltype: leukocyte in Small-Intestine
# Subsetting celltype: Fraction A pre-pro B cell in Small-Intestine
# Subsetting celltype: alveolar macrophage in Small-Intestine
# Subsetting celltype: proerythroblast in Small-Intestine
# Subsetting celltype: neuroendocrine cell in Small-Intestine
# Subsetting celltype: cardiac muscle cell in Small-Intestine
# Subsetting celltype: luminal epithelial cell of mammary gland in Small-Intestine
# Subsetting celltype: monocyte in Small-Intestine
# Subsetting celltype: unassigned in Small-Intestine
# Subsetting celltype: B cell in Small-Intestine
# Subsetting celltype: blood cell in Small-Intestine
# Subsetting celltype: kidney cell in Small-Intestine
# Subsetting tissue: Thymus
# Subsetting celltype: basophil in Thymus
# Subsetting celltype: classical monocyte in Thymus
# Subsetting celltype: skeletal muscle satellite cell in Thymus
# Subsetting celltype: endocardial cell in Thymus
# Subsetting celltype: bladder cell in Thymus
# Subsetting celltype: myeloid cell in Thymus
# Subsetting celltype: epithelial cell in Thymus
# Subsetting celltype: Langerhans cell in Thymus
# Subsetting celltype: immature B cell in Thymus
# Subsetting celltype: hematopoietic precursor cell in Thymus
# Subsetting celltype: non-classical monocyte in Thymus
# Subsetting celltype: fibroblast in Thymus
# Subsetting celltype: DN1 thymic pro-T cell in Thymus
# Subsetting celltype: T cell in Thymus
# Subsetting celltype: natural killer cell in Thymus
# Subsetting celltype: promonocyte in Thymus
# Subsetting celltype: endothelial cell in Thymus
# Subsetting celltype: macrophage in Thymus
# Subsetting celltype: leukocyte in Thymus
# Subsetting celltype: Fraction A pre-pro B cell in Thymus
# Subsetting celltype: alveolar macrophage in Thymus
# Subsetting celltype: neuroendocrine cell in Thymus
# Subsetting celltype: bladder urothelial cell in Thymus
# Subsetting celltype: luminal epithelial cell of mammary gland in Thymus
# Subsetting celltype: monocyte in Thymus
# Subsetting celltype: unassigned in Thymus
# Subsetting celltype: dendritic cell in Thymus
# Subsetting celltype: B cell in Thymus
# Subsetting celltype: blood cell in Thymus
# Subsetting celltype: kidney cell in Thymus
# Subsetting tissue: MammaryGland.Involution
# Subsetting celltype: Fraction A pre-pro B cell in MammaryGland.Involution
# Subsetting celltype: hematopoietic precursor cell in MammaryGland.Involution
# Subsetting celltype: T cell in MammaryGland.Involution
# Subsetting celltype: promonocyte in MammaryGland.Involution
# Subsetting celltype: kidney cell in MammaryGland.Involution
# Subsetting celltype: granulocyte in MammaryGland.Involution
# Subsetting celltype: natural killer cell in MammaryGland.Involution
# Subsetting celltype: unassigned in MammaryGland.Involution
# Subsetting celltype: dendritic cell in MammaryGland.Involution
# Subsetting celltype: B cell in MammaryGland.Involution
# Subsetting celltype: immature T cell in MammaryGland.Involution
# Subsetting celltype: DN1 thymic pro-T cell in MammaryGland.Involution
# Subsetting tissue: Fetal_Intestine
# Subsetting celltype: basophil in Fetal_Intestine
# Subsetting celltype: classical monocyte in Fetal_Intestine
# Subsetting celltype: skeletal muscle satellite cell in Fetal_Intestine
# Subsetting celltype: bladder cell in Fetal_Intestine
# Subsetting celltype: myeloid cell in Fetal_Intestine
# Subsetting celltype: granulocyte in Fetal_Intestine
# Subsetting celltype: mesenchymal cell in Fetal_Intestine
# Subsetting celltype: granulocytopoietic cell in Fetal_Intestine
# Subsetting celltype: hematopoietic precursor cell in Fetal_Intestine
# Subsetting celltype: non-classical monocyte in Fetal_Intestine
# Subsetting celltype: immature T cell in Fetal_Intestine
# Subsetting celltype: late pro-B cell in Fetal_Intestine
# Subsetting celltype: promonocyte in Fetal_Intestine
# Subsetting celltype: T cell in Fetal_Intestine
# Subsetting celltype: natural killer cell in Fetal_Intestine
# Subsetting celltype: macrophage in Fetal_Intestine
# Subsetting celltype: erythroblast in Fetal_Intestine
# Subsetting celltype: hepatocyte in Fetal_Intestine
# Subsetting celltype: leukocyte in Fetal_Intestine
# Subsetting celltype: Fraction A pre-pro B cell in Fetal_Intestine
# Subsetting celltype: alveolar macrophage in Fetal_Intestine
# Subsetting celltype: proerythroblast in Fetal_Intestine
# Subsetting celltype: luminal epithelial cell of mammary gland in Fetal_Intestine
# Subsetting celltype: monocyte in Fetal_Intestine
# Subsetting celltype: unassigned in Fetal_Intestine
# Subsetting celltype: blood cell in Fetal_Intestine
# Subsetting celltype: kidney cell in Fetal_Intestine
# Subsetting tissue: Ovary
# Subsetting celltype: basophil in Ovary
# Subsetting celltype: classical monocyte in Ovary
# Subsetting celltype: skeletal muscle satellite cell in Ovary
# Subsetting celltype: bladder cell in Ovary
# Subsetting celltype: myeloid cell in Ovary
# Subsetting celltype: granulocyte in Ovary
# Subsetting celltype: mesenchymal cell in Ovary
# Subsetting celltype: immature B cell in Ovary
# Subsetting celltype: mesangial cell in Ovary
# Subsetting celltype: granulocytopoietic cell in Ovary
# Subsetting celltype: kidney capillary endothelial cell in Ovary
# Subsetting celltype: hematopoietic precursor cell in Ovary
# Subsetting celltype: non-classical monocyte in Ovary
# Subsetting celltype: fibroblast in Ovary
# Subsetting celltype: DN1 thymic pro-T cell in Ovary
# Subsetting celltype: late pro-B cell in Ovary
# Subsetting celltype: T cell in Ovary
# Subsetting celltype: mesenchymal stem cell in Ovary
# Subsetting celltype: promonocyte in Ovary
# Subsetting celltype: natural killer cell in Ovary
# Subsetting celltype: mast cell in Ovary
# Subsetting celltype: endothelial cell in Ovary
# Subsetting celltype: erythroblast in Ovary
# Subsetting celltype: early pro-B cell in Ovary
# Subsetting celltype: Fraction A pre-pro B cell in Ovary
# Subsetting celltype: alveolar macrophage in Ovary
# Subsetting celltype: proerythroblast in Ovary
# Subsetting celltype: neuroendocrine cell in Ovary
# Subsetting celltype: lung endothelial cell in Ovary
# Subsetting celltype: monocyte in Ovary
# Subsetting celltype: unassigned in Ovary
# Subsetting celltype: dendritic cell in Ovary
# Subsetting celltype: B cell in Ovary
# Subsetting celltype: blood cell in Ovary
# Subsetting celltype: kidney cell in Ovary
# Subsetting tissue: Prostate
# Subsetting celltype: basophil in Prostate
# Subsetting celltype: classical monocyte in Prostate
# Subsetting celltype: skeletal muscle satellite cell in Prostate
# Subsetting celltype: bladder cell in Prostate
# Subsetting celltype: granulocyte in Prostate
# Subsetting celltype: mesenchymal cell in Prostate
# Subsetting celltype: immature B cell in Prostate
# Subsetting celltype: mesangial cell in Prostate
# Subsetting celltype: granulocytopoietic cell in Prostate
# Subsetting celltype: hematopoietic precursor cell in Prostate
# Subsetting celltype: non-classical monocyte in Prostate
# Subsetting celltype: fibroblast in Prostate
# Subsetting celltype: DN1 thymic pro-T cell in Prostate
# Subsetting celltype: late pro-B cell in Prostate
# Subsetting celltype: T cell in Prostate
# Subsetting celltype: promonocyte in Prostate
# Subsetting celltype: mesenchymal stem cell in Prostate
# Subsetting celltype: natural killer cell in Prostate
# Subsetting celltype: endothelial cell in Prostate
# Subsetting celltype: macrophage in Prostate
# Subsetting celltype: early pro-B cell in Prostate
# Subsetting celltype: leukocyte in Prostate
# Subsetting celltype: alveolar macrophage in Prostate
# Subsetting celltype: neuroendocrine cell in Prostate
# Subsetting celltype: cardiac muscle cell in Prostate
# Subsetting celltype: monocyte in Prostate
# Subsetting celltype: unassigned in Prostate
# Subsetting celltype: B cell in Prostate
# Subsetting tissue: Liver
# Subsetting celltype: classical monocyte in Liver
# Subsetting celltype: endocardial cell in Liver
# Subsetting celltype: bladder cell in Liver
# Subsetting celltype: myeloid cell in Liver
# Subsetting celltype: granulocyte in Liver
# Subsetting celltype: ciliated columnar cell of tracheobronchial tree in Liver
# Subsetting celltype: Langerhans cell in Liver
# Subsetting celltype: immature B cell in Liver
# Subsetting celltype: granulocytopoietic cell in Liver
# Subsetting celltype: hematopoietic precursor cell in Liver
# Subsetting celltype: type II pneumocyte in Liver
# Subsetting celltype: non-classical monocyte in Liver
# Subsetting celltype: fibroblast in Liver
# Subsetting celltype: DN1 thymic pro-T cell in Liver
# Subsetting celltype: late pro-B cell in Liver
# Subsetting celltype: T cell in Liver
# Subsetting celltype: natural killer cell in Liver
# Subsetting celltype: mesenchymal stem cell in Liver
# Subsetting celltype: mast cell in Liver
# Subsetting celltype: endothelial cell in Liver
# Subsetting celltype: macrophage in Liver
# Subsetting celltype: early pro-B cell in Liver
# Subsetting celltype: stromal cell in Liver
# Subsetting celltype: leukocyte in Liver
# Subsetting celltype: alveolar macrophage in Liver
# Subsetting celltype: lung endothelial cell in Liver
# Subsetting celltype: luminal epithelial cell of mammary gland in Liver
# Subsetting celltype: unassigned in Liver
# Subsetting celltype: B cell in Liver
# Subsetting celltype: dendritic cell in Liver
# Subsetting celltype: blood cell in Liver
# Subsetting celltype: kidney cell in Liver
# Subsetting tissue: Bladder
# Subsetting celltype: classical monocyte in Bladder
# Subsetting celltype: endocardial cell in Bladder
# Subsetting celltype: bladder cell in Bladder
# Subsetting celltype: myeloid cell in Bladder
# Subsetting celltype: Langerhans cell in Bladder
# Subsetting celltype: mesangial cell in Bladder
# Subsetting celltype: non-classical monocyte in Bladder
# Subsetting celltype: fibroblast in Bladder
# Subsetting celltype: DN1 thymic pro-T cell in Bladder
# Subsetting celltype: promonocyte in Bladder
# Subsetting celltype: mesenchymal stem cell in Bladder
# Subsetting celltype: T cell in Bladder
# Subsetting celltype: natural killer cell in Bladder
# Subsetting celltype: endothelial cell in Bladder
# Subsetting celltype: macrophage in Bladder
# Subsetting celltype: stromal cell in Bladder
# Subsetting celltype: bladder urothelial cell in Bladder
# Subsetting celltype: neuroendocrine cell in Bladder
# Subsetting celltype: lung endothelial cell in Bladder
# Subsetting celltype: unassigned in Bladder
# Subsetting celltype: blood cell in Bladder
# Subsetting celltype: kidney cell in Bladder
# Subsetting tissue: Fetal_Lung
# Subsetting celltype: basophil in Fetal_Lung
# Subsetting celltype: classical monocyte in Fetal_Lung
# Subsetting celltype: skeletal muscle satellite cell in Fetal_Lung
# Subsetting celltype: endocardial cell in Fetal_Lung
# Subsetting celltype: duct epithelial cell in Fetal_Lung
# Subsetting celltype: bladder cell in Fetal_Lung
# Subsetting celltype: myeloid cell in Fetal_Lung
# Subsetting celltype: kidney loop of Henle ascending limb epithelial cell in Fetal_Lung
# Subsetting celltype: granulocyte in Fetal_Lung
# Subsetting celltype: epithelial cell in Fetal_Lung
# Subsetting celltype: Langerhans cell in Fetal_Lung
# Subsetting celltype: granulocytopoietic cell in Fetal_Lung
# Subsetting celltype: kidney capillary endothelial cell in Fetal_Lung
# Subsetting celltype: hematopoietic precursor cell in Fetal_Lung
# Subsetting celltype: non-classical monocyte in Fetal_Lung
# Subsetting celltype: immature T cell in Fetal_Lung
# Subsetting celltype: fibroblast in Fetal_Lung
# Subsetting celltype: DN1 thymic pro-T cell in Fetal_Lung
# Subsetting celltype: late pro-B cell in Fetal_Lung
# Subsetting celltype: promonocyte in Fetal_Lung
# Subsetting celltype: T cell in Fetal_Lung
# Subsetting celltype: natural killer cell in Fetal_Lung
# Subsetting celltype: mesenchymal stem cell in Fetal_Lung
# Subsetting celltype: endothelial cell in Fetal_Lung
# Subsetting celltype: macrophage in Fetal_Lung
# Subsetting celltype: leukocyte in Fetal_Lung
# Subsetting celltype: Fraction A pre-pro B cell in Fetal_Lung
# Subsetting celltype: alveolar macrophage in Fetal_Lung
# Subsetting celltype: kidney proximal straight tubule epithelial cell in Fetal_Lung
# Subsetting celltype: proerythroblast in Fetal_Lung
# Subsetting celltype: bladder urothelial cell in Fetal_Lung
# Subsetting celltype: luminal epithelial cell of mammary gland in Fetal_Lung
# Subsetting celltype: monocyte in Fetal_Lung
# Subsetting celltype: unassigned in Fetal_Lung
# Subsetting celltype: B cell in Fetal_Lung
# Subsetting celltype: kidney collecting duct epithelial cell in Fetal_Lung
# Subsetting celltype: blood cell in Fetal_Lung
# Subsetting celltype: kidney cell in Fetal_Lung
# Subsetting tissue: Kidney
# Subsetting celltype: classical monocyte in Kidney
# Subsetting celltype: bladder cell in Kidney
# Subsetting celltype: myeloid cell in Kidney
# Subsetting celltype: granulocyte in Kidney
# Subsetting celltype: ciliated columnar cell of tracheobronchial tree in Kidney
# Subsetting celltype: Langerhans cell in Kidney
# Subsetting celltype: immature B cell in Kidney
# Subsetting celltype: granulocytopoietic cell in Kidney
# Subsetting celltype: hematopoietic precursor cell in Kidney
# Subsetting celltype: non-classical monocyte in Kidney
# Subsetting celltype: type II pneumocyte in Kidney
# Subsetting celltype: fibroblast in Kidney
# Subsetting celltype: DN1 thymic pro-T cell in Kidney
# Subsetting celltype: late pro-B cell in Kidney
# Subsetting celltype: T cell in Kidney
# Subsetting celltype: natural killer cell in Kidney
# Subsetting celltype: mesenchymal stem cell in Kidney
# Subsetting celltype: promonocyte in Kidney
# Subsetting celltype: mast cell in Kidney
# Subsetting celltype: endothelial cell in Kidney
# Subsetting celltype: macrophage in Kidney
# Subsetting celltype: hepatocyte in Kidney
# Subsetting celltype: stromal cell in Kidney
# Subsetting celltype: leukocyte in Kidney
# Subsetting celltype: alveolar macrophage in Kidney
# Subsetting celltype: neuroendocrine cell in Kidney
# Subsetting celltype: luminal epithelial cell of mammary gland in Kidney
# Subsetting celltype: lung endothelial cell in Kidney
# Subsetting celltype: monocyte in Kidney
# Subsetting celltype: unassigned in Kidney
# Subsetting celltype: dendritic cell in Kidney
# Subsetting celltype: B cell in Kidney
# Subsetting celltype: blood cell in Kidney
# Subsetting celltype: kidney cell in Kidney
# Subsetting tissue: Fetal-Liver
# Subsetting celltype: basophil in Fetal-Liver
# Subsetting celltype: classical monocyte in Fetal-Liver
# Subsetting celltype: skeletal muscle satellite cell in Fetal-Liver
# Subsetting celltype: duct epithelial cell in Fetal-Liver
# Subsetting celltype: bladder cell in Fetal-Liver
# Subsetting celltype: myeloid cell in Fetal-Liver
# Subsetting celltype: granulocyte in Fetal-Liver
# Subsetting celltype: mesenchymal cell in Fetal-Liver
# Subsetting celltype: granulocytopoietic cell in Fetal-Liver
# Subsetting celltype: hematopoietic precursor cell in Fetal-Liver
# Subsetting celltype: non-classical monocyte in Fetal-Liver
# Subsetting celltype: DN1 thymic pro-T cell in Fetal-Liver
# Subsetting celltype: promonocyte in Fetal-Liver
# Subsetting celltype: T cell in Fetal-Liver
# Subsetting celltype: mast cell in Fetal-Liver
# Subsetting celltype: macrophage in Fetal-Liver
# Subsetting celltype: erythroblast in Fetal-Liver
# Subsetting celltype: leukocyte in Fetal-Liver
# Subsetting celltype: alveolar macrophage in Fetal-Liver
# Subsetting celltype: proerythroblast in Fetal-Liver
# Subsetting celltype: bladder urothelial cell in Fetal-Liver
# Subsetting celltype: luminal epithelial cell of mammary gland in Fetal-Liver
# Subsetting celltype: monocyte in Fetal-Liver
# Subsetting celltype: unassigned in Fetal-Liver
# Subsetting celltype: kidney cell in Fetal-Liver
# Subsetting tissue: Placenta
# Subsetting celltype: basophil in Placenta
# Subsetting celltype: classical monocyte in Placenta
# Subsetting celltype: endocardial cell in Placenta
# Subsetting celltype: skeletal muscle satellite cell in Placenta
# Subsetting celltype: bladder cell in Placenta
# Subsetting celltype: myeloid cell in Placenta
# Subsetting celltype: granulocyte in Placenta
# Subsetting celltype: mesenchymal cell in Placenta
# Subsetting celltype: immature B cell in Placenta
# Subsetting celltype: mesangial cell in Placenta
# Subsetting celltype: granulocytopoietic cell in Placenta
# Subsetting celltype: hematopoietic precursor cell in Placenta
# Subsetting celltype: non-classical monocyte in Placenta
# Subsetting celltype: immature T cell in Placenta
# Subsetting celltype: fibroblast in Placenta
# Subsetting celltype: DN1 thymic pro-T cell in Placenta
# Subsetting celltype: late pro-B cell in Placenta
# Subsetting celltype: promonocyte in Placenta
# Subsetting celltype: mesenchymal stem cell in Placenta
# Subsetting celltype: T cell in Placenta
# Subsetting celltype: natural killer cell in Placenta
# Subsetting celltype: endothelial cell in Placenta
# Subsetting celltype: macrophage in Placenta
# Subsetting celltype: early pro-B cell in Placenta
# Subsetting celltype: stromal cell in Placenta
# Subsetting celltype: leukocyte in Placenta
# Subsetting celltype: Fraction A pre-pro B cell in Placenta
# Subsetting celltype: alveolar macrophage in Placenta
# Subsetting celltype: neuroendocrine cell in Placenta
# Subsetting celltype: cardiac muscle cell in Placenta
# Subsetting celltype: bladder urothelial cell in Placenta
# Subsetting celltype: monocyte in Placenta
# Subsetting celltype: unassigned in Placenta
# Subsetting celltype: blood cell in Placenta
# Subsetting celltype: kidney cell in Placenta
# Subsetting tissue: Pancreas
# Subsetting celltype: basophil in Pancreas
# Subsetting celltype: classical monocyte in Pancreas
# Subsetting celltype: skeletal muscle satellite cell in Pancreas
# Subsetting celltype: endocardial cell in Pancreas
# Subsetting celltype: bladder cell in Pancreas
# Subsetting celltype: granulocyte in Pancreas
# Subsetting celltype: mesenchymal cell in Pancreas
# Subsetting celltype: granulocytopoietic cell in Pancreas
# Subsetting celltype: hematopoietic precursor cell in Pancreas
# Subsetting celltype: non-classical monocyte in Pancreas
# Subsetting celltype: fibroblast in Pancreas
# Subsetting celltype: late pro-B cell in Pancreas
# Subsetting celltype: promonocyte in Pancreas
# Subsetting celltype: T cell in Pancreas
# Subsetting celltype: mesenchymal stem cell in Pancreas
# Subsetting celltype: endothelial cell in Pancreas
# Subsetting celltype: alveolar macrophage in Pancreas
# Subsetting celltype: neuroendocrine cell in Pancreas
# Subsetting celltype: lung endothelial cell in Pancreas
# Subsetting celltype: monocyte in Pancreas
# Subsetting celltype: unassigned in Pancreas
# Subsetting celltype: B cell in Pancreas
# Subsetting celltype: blood cell in Pancreas
# Subsetting tissue: Testis
# Subsetting celltype: basophil in Testis
# Subsetting celltype: classical monocyte in Testis
# Subsetting celltype: skeletal muscle satellite cell in Testis
# Subsetting celltype: endocardial cell in Testis
# Subsetting celltype: bladder cell in Testis
# Subsetting celltype: myeloid cell in Testis
# Subsetting celltype: granulocyte in Testis
# Subsetting celltype: Langerhans cell in Testis
# Subsetting celltype: immature B cell in Testis
# Subsetting celltype: mesangial cell in Testis
# Subsetting celltype: granulocytopoietic cell in Testis
# Subsetting celltype: kidney capillary endothelial cell in Testis
# Subsetting celltype: hematopoietic precursor cell in Testis
# Subsetting celltype: non-classical monocyte in Testis
# Subsetting celltype: fibroblast in Testis
# Subsetting celltype: DN1 thymic pro-T cell in Testis
# Subsetting celltype: late pro-B cell in Testis
# Subsetting celltype: T cell in Testis
# Subsetting celltype: mesenchymal stem cell in Testis
# Subsetting celltype: natural killer cell in Testis
# Subsetting celltype: promonocyte in Testis
# Subsetting celltype: mast cell in Testis
# Subsetting celltype: endothelial cell in Testis
# Subsetting celltype: macrophage in Testis
# Subsetting celltype: erythroblast in Testis
# Subsetting celltype: early pro-B cell in Testis
# Subsetting celltype: stromal cell in Testis
# Subsetting celltype: basal cell in Testis
# Subsetting celltype: leukocyte in Testis
# Subsetting celltype: Fraction A pre-pro B cell in Testis
# Subsetting celltype: alveolar macrophage in Testis
# Subsetting celltype: proerythroblast in Testis
# Subsetting celltype: neuroendocrine cell in Testis
# Subsetting celltype: luminal epithelial cell of mammary gland in Testis
# Subsetting celltype: monocyte in Testis
# Subsetting celltype: unassigned in Testis
# Subsetting celltype: B cell in Testis
# Subsetting celltype: dendritic cell in Testis
# Subsetting celltype: kidney collecting duct epithelial cell in Testis
# Subsetting celltype: blood cell in Testis
# Subsetting celltype: kidney cell in Testis
# Subsetting tissue: Spleen
# Subsetting celltype: basophil in Spleen
# Subsetting celltype: classical monocyte in Spleen
# Subsetting celltype: skeletal muscle satellite cell in Spleen
# Subsetting celltype: bladder cell in Spleen
# Subsetting celltype: epithelial cell in Spleen
# Subsetting celltype: Langerhans cell in Spleen
# Subsetting celltype: mesangial cell in Spleen
# Subsetting celltype: hematopoietic precursor cell in Spleen
# Subsetting celltype: non-classical monocyte in Spleen
# Subsetting celltype: fibroblast in Spleen
# Subsetting celltype: T cell in Spleen
# Subsetting celltype: endothelial cell in Spleen
# Subsetting celltype: macrophage in Spleen
# Subsetting celltype: basal cell in Spleen
# Subsetting celltype: leukocyte in Spleen
# Subsetting celltype: alveolar macrophage in Spleen
# Subsetting celltype: neuroendocrine cell in Spleen
# Subsetting celltype: cardiac muscle cell in Spleen
# Subsetting celltype: luminal epithelial cell of mammary gland in Spleen
# Subsetting celltype: bladder urothelial cell in Spleen
# Subsetting celltype: unassigned in Spleen
# Subsetting celltype: kidney collecting duct epithelial cell in Spleen
# Subsetting celltype: blood cell in Spleen
# Subsetting celltype: kidney cell in Spleen
# Subsetting tissue: Mesenchymal-Stem-Cell-Cultured
# Subsetting celltype: hematopoietic precursor cell in Mesenchymal-Stem-Cell-Cultured
# Subsetting celltype: myeloid cell in Mesenchymal-Stem-Cell-Cultured
# Subsetting celltype: T cell in Mesenchymal-Stem-Cell-Cultured
# Subsetting celltype: unassigned in Mesenchymal-Stem-Cell-Cultured
# Subsetting celltype: macrophage in Mesenchymal-Stem-Cell-Cultured
# Subsetting celltype: blood cell in Mesenchymal-Stem-Cell-Cultured
# Subsetting celltype: DN1 thymic pro-T cell in Mesenchymal-Stem-Cell-Cultured
# Subsetting tissue: Muscle
# Subsetting celltype: hematopoietic precursor cell in Muscle
# Subsetting celltype: unassigned in Muscle
# Subsetting celltype: T cell in Muscle
# Subsetting celltype: kidney cell in Muscle
# Subsetting tissue: Bone_Marrow_Mesenchyme
# Subsetting celltype: basophil in Bone_Marrow_Mesenchyme
# Subsetting celltype: classical monocyte in Bone_Marrow_Mesenchyme
# Subsetting celltype: skeletal muscle satellite cell in Bone_Marrow_Mesenchyme
# Subsetting celltype: endocardial cell in Bone_Marrow_Mesenchyme
# Subsetting celltype: bladder cell in Bone_Marrow_Mesenchyme
# Subsetting celltype: myeloid cell in Bone_Marrow_Mesenchyme
# Subsetting celltype: granulocyte in Bone_Marrow_Mesenchyme
# Subsetting celltype: mesenchymal cell in Bone_Marrow_Mesenchyme
# Subsetting celltype: granulocytopoietic cell in Bone_Marrow_Mesenchyme
# Subsetting celltype: hematopoietic precursor cell in Bone_Marrow_Mesenchyme
# Subsetting celltype: non-classical monocyte in Bone_Marrow_Mesenchyme
# Subsetting celltype: immature T cell in Bone_Marrow_Mesenchyme
# Subsetting celltype: fibroblast in Bone_Marrow_Mesenchyme
# Subsetting celltype: DN1 thymic pro-T cell in Bone_Marrow_Mesenchyme
# Subsetting celltype: late pro-B cell in Bone_Marrow_Mesenchyme
# Subsetting celltype: T cell in Bone_Marrow_Mesenchyme
# Subsetting celltype: natural killer cell in Bone_Marrow_Mesenchyme
# Subsetting celltype: promonocyte in Bone_Marrow_Mesenchyme
# Subsetting celltype: endothelial cell in Bone_Marrow_Mesenchyme
# Subsetting celltype: macrophage in Bone_Marrow_Mesenchyme
# Subsetting celltype: leukocyte in Bone_Marrow_Mesenchyme
# Subsetting celltype: Fraction A pre-pro B cell in Bone_Marrow_Mesenchyme
# Subsetting celltype: alveolar macrophage in Bone_Marrow_Mesenchyme
# Subsetting celltype: proerythroblast in Bone_Marrow_Mesenchyme
# Subsetting celltype: luminal epithelial cell of mammary gland in Bone_Marrow_Mesenchyme
# Subsetting celltype: monocyte in Bone_Marrow_Mesenchyme
# Subsetting celltype: unassigned in Bone_Marrow_Mesenchyme
# Subsetting celltype: B cell in Bone_Marrow_Mesenchyme
# Subsetting celltype: kidney cell in Bone_Marrow_Mesenchyme
# Subsetting tissue: Embryonic-Stem-Cell
# Subsetting celltype: basophil in Embryonic-Stem-Cell
# Subsetting celltype: classical monocyte in Embryonic-Stem-Cell
# Subsetting celltype: skeletal muscle satellite cell in Embryonic-Stem-Cell
# Subsetting celltype: endocardial cell in Embryonic-Stem-Cell
# Subsetting celltype: bladder cell in Embryonic-Stem-Cell
# Subsetting celltype: myeloid cell in Embryonic-Stem-Cell
# Subsetting celltype: granulocyte in Embryonic-Stem-Cell
# Subsetting celltype: mesenchymal cell in Embryonic-Stem-Cell
# Subsetting celltype: hematopoietic precursor cell in Embryonic-Stem-Cell
# Subsetting celltype: non-classical monocyte in Embryonic-Stem-Cell
# Subsetting celltype: immature T cell in Embryonic-Stem-Cell
# Subsetting celltype: fibroblast in Embryonic-Stem-Cell
# Subsetting celltype: DN1 thymic pro-T cell in Embryonic-Stem-Cell
# Subsetting celltype: late pro-B cell in Embryonic-Stem-Cell
# Subsetting celltype: T cell in Embryonic-Stem-Cell
# Subsetting celltype: promonocyte in Embryonic-Stem-Cell
# Subsetting celltype: natural killer cell in Embryonic-Stem-Cell
# Subsetting celltype: macrophage in Embryonic-Stem-Cell
# Subsetting celltype: erythroblast in Embryonic-Stem-Cell
# Subsetting celltype: basal cell in Embryonic-Stem-Cell
# Subsetting celltype: leukocyte in Embryonic-Stem-Cell
# Subsetting celltype: Fraction A pre-pro B cell in Embryonic-Stem-Cell
# Subsetting celltype: alveolar macrophage in Embryonic-Stem-Cell
# Subsetting celltype: proerythroblast in Embryonic-Stem-Cell
# Subsetting celltype: bladder urothelial cell in Embryonic-Stem-Cell
# Subsetting celltype: luminal epithelial cell of mammary gland in Embryonic-Stem-Cell
# Subsetting celltype: monocyte in Embryonic-Stem-Cell
# Subsetting celltype: unassigned in Embryonic-Stem-Cell
# Subsetting celltype: B cell in Embryonic-Stem-Cell
# Subsetting celltype: kidney cell in Embryonic-Stem-Cell

# %%
mca
# Out:
# AnnData object with n_obs × n_vars = 11371 × 39855
#     obs: 'celltype'

# %%
mca.write('/work/sduknn/Andreas/TM_MCA/MCA/mca_20_cell_pseudobulk.h5ad')
facs.write('/work/sduknn/Andreas/TM_MCA/TM/facs_20_cell_pseudobulk.h5ad')
droplet.write('/work/sduknn/Andreas/TM_MCA/TM/droplet_20_cell_pseudobulk.h5ad')
